# %%
import pandas as pd

# %%
combined_df = pd.read_csv('combined_data.csv')

combined_df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0       295665.0      Macbook Pro Laptop               1.0     1700.00
# 1       295666.0      LG Washing Machine               1.0      600.00
# 2       295667.0    USB-C Charging Cable               1.0       11.95
# 3       295668.0        27in FHD Monitor               1.0      149.99
# 4       295669.0    USB-C Charging Cable               1.0       11.95
# ...          ...                     ...               ...         ...
# 186490  222905.0  AAA Batteries (4-pack)               1.0        2.99
# 186491  222906.0        27in FHD Monitor               1.0      149.99
# 186492  222907.0    USB-C Charging Cable               1.0       11.95
# 186493  222908.0    USB-C Charging Cable               1.0       11.95
# 186494  222909.0  AAA Batteries (4-pack)               1.0        2.99
#
#               Order Date                        Purchase Address
# ...

# %%
no_empty_row_combined_df = combined_df.dropna(how='all')

no_empty_row_combined_df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0       295665.0      Macbook Pro Laptop               1.0     1700.00
# 1       295666.0      LG Washing Machine               1.0      600.00
# 2       295667.0    USB-C Charging Cable               1.0       11.95
# 3       295668.0        27in FHD Monitor               1.0      149.99
# 4       295669.0    USB-C Charging Cable               1.0       11.95
# ...          ...                     ...               ...         ...
# 186490  222905.0  AAA Batteries (4-pack)               1.0        2.99
# 186491  222906.0        27in FHD Monitor               1.0      149.99
# 186492  222907.0    USB-C Charging Cable               1.0       11.95
# 186493  222908.0    USB-C Charging Cable               1.0       11.95
# 186494  222909.0  AAA Batteries (4-pack)               1.0        2.99
#
#               Order Date                        Purchase Address
# ...

# %%
no_empty_row_combined_df.to_csv('clean_combined_data.csv', index = False)
